# %%
import glob
import pandas as pd
leactures_CRN = glob.glob('lectures-CRNs/*.csv')
groupedStudents = glob.glob('groupedStudents/*.csv')
my_CRN='CRNs/roster_CRN_71160.csv'
my_CRN_df=pd.read_csv(my_CRN)
# Concatenate the list of dataframes
groupedStudents_df = pd.concat([pd.read_csv(i) for i in groupedStudents], ignore_index=True)
# Assuming you have two dataframes: dfA and dfB
# Replace 'common_column_A' and 'common_column_B' with the actual column names

# To find missing rows in dfB
missing_students_df = my_CRN_df.merge(groupedStudents_df, 
                             left_on='Student ID', 
                             right_on='SIS Login ID', 

                             how='left', indicator=True).query(
                                 '_merge == "left_only"').drop('_merge', axis=1)

print(missing_students_df.info())
print(missing_students_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 1 to 51
# Data columns (total 100 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   #                                                                                                     9 non-null      int64
#  1   Term Code                                                                                             9 non-null      int64
#  2   CRN                                                                                                   9 non-null      int64
#  3   Course Code                                                                                           9 non-null      object
#  4   Student ID                                                                                            9 non-null      int64
#  5   Last Name                                                                                             9 non-null      object
#  6   First Name                                                                                            9 non-null      object
#  7   Middle                                                                                                6 non-null      object
#  8   Email                                                                                                 9 non-null      object
#  9   Student                                                                                               0 non-null      object
#  10  ID                                                                                                    0 non-null      float64
#  11  SIS Login ID                                                                                          0 non-null      float64
#  12  Section                                                                                               0 non-null      object
#  13  Tutorial 1 (148250)                                                                                   0 non-null      float64
#  14  Tutorial 2 (148252)                                                                                   0 non-null      float64
#  15  Tutorial 3 (148253)                                                                                   0 non-null      float64
#  16  Tutorial 4 (148254)                                                                                   0 non-null      float64
#  17  Tutorial 5 (148255)                                                                                   0 non-null      float64
#  18  Tutorial 6 (148256)                                                                                   0 non-null      float64
#  19  Tutorial 7 (148257)                                                                                   0 non-null      float64
#  20  Tutorial 8 (148258)                                                                                   0 non-null      float64
#  21  Tutorial 9 (148259)                                                                                   0 non-null      float64
#  22  Tutorial 10 (148251)                                                                                  0 non-null      float64
#  23  Programming Assignment #2 (148249)                                                                    0 non-null      object
#  24  Programming Assignment #1 (148248)                                                                    0 non-null      object
#  25  Quiz 4- Requires Respondus LockDown Browser (148232)                                                  0 non-null      object
#  26  Quiz 3- Requires Respondus LockDown Browser (148240)                                                  0 non-null      object
#  27  Quiz 2- Requires Respondus LockDown Browser (148241)                                                  0 non-null      object
#  28  Quiz 1- Requires Respondus LockDown Browser (148247)                                                  0 non-null      object
#  29  Assignments Current Points                                                                            0 non-null      object
#  30  Assignments Final Points                                                                              0 non-null      object
#  31  Assignments Current Score                                                                             0 non-null      object
#  32  Assignments Unposted Current Score                                                                    0 non-null      object
#  33  Assignments Final Score                                                                               0 non-null      object
#  34  Assignments Unposted Final Score                                                                      0 non-null      object
Requires Respondus LockDown Browser- Requires Respondus LockDown Browser (146773)  0 non-null      object
#  79  Quiz 3- Selection-Requires Respondus LockDown Browser- Requires Respondus LockDown Browser (146772)   0 non-null      object
#  80  Quiz 2- Simple C++ - Requires Respondus LockDown Browser (146760)                                     0 non-null      object
#  81  Quiz 1- Introduction- Requires Respondus LockDown Browser (146763)                                    0 non-null      object
#  82  Quiz-6-Functions1- Requires Respondus LockDown Browser (146755)                                       0 non-null      object
#  83  Quiz 9-ID Arrays2- Requires Respondus LockDown Browser (146761)                                       0 non-null      object
#  84  Tutorial 1 (148218)                                                                                   0 non-null      float64
#  85  Tutorial 2 (148220)                                                                                   0 non-null      float64
#  86  Tutorial 3 (148221)                                                                                   0 non-null      float64
#  87  Tutorial 4 (148222)                                                                                   0 non-null      float64
#  88  Tutorial 5 (148223)                                                                                   0 non-null      float64
#  89  Tutorial 6 (148224)                                                                                   0 non-null      float64
#  90  Tutorial 7 (148225)                                                                                   0 non-null      float64
#  91  Tutorial 8 (148226)                                                                                   0 non-null      float64
#  92  Tutorial 9 (148227)                                                                                   0 non-null      float64
#  93  Tutorial 10 (148219)                                                                                  0 non-null      float64
#  94  Programming Assignment #2 (148217)                                                                    0 non-null      object
#  95  Programming Assignment #1 (148216)                                                                    0 non-null      object
#  96  Quiz 4- Requires Respondus LockDown Browser (148207)                                                  0 non-null      object
#  97  Quiz 3- Requires Respondus LockDown Browser (148204)                                                  0 non-null      object
#  98  Quiz 2- Requires Respondus LockDown Browser (148214)                                                  0 non-null      object
#  99  Quiz 1- Requires Respondus LockDown Browser (148211)                                                  0 non-null      object
# dtypes: float64(34), int64(4), object(62)
# memory usage: 7.1+ KB
# None
#      #  Term Code    CRN Course Code  Student ID Last Name First Name  \
# 1    2     202401  71160  ENGR 1200U   100918191   Acharya       Ashi
# 10  11     202401  71160  ENGR 1200U   100855555     Amjad    Imtihal
# 11  12     202401  71160  ENGR 1200U   100915835      Ayub   Muhammad
# 12  13     202401  71160  ENGR 1200U   100914683    Bakkar  Jahed-Bin
# 21  22     202401  71160  ENGR 1200U   100905250    Dunbar       Jack
#
#       Middle                     Email Student  ...  Tutorial 7 (148225)  \
# 1        NaN     ashi.acharya@uoit.net     NaN  ...                  NaN
# 10       NaN    imtihal.amjad@uoit.net     NaN  ...                  NaN
# 11  Abdullah    muhammad.ayub@uoit.net     NaN  ...                  NaN
# 12       NaN  jahedbin.bakkar@uoit.net     NaN  ...                  NaN
# 21     Ethan      jack.dunbar@uoit.net     NaN  ...                  NaN
#
#     Tutorial 8 (148226) Tutorial 9 (148227)  Tutorial 10 (148219)  \
# 1                   NaN                 NaN                   NaN
# 10                  NaN                 NaN                   NaN
# 11                  NaN                 NaN                   NaN
# 12                  NaN                 NaN                   NaN
# 21                  NaN                 NaN                   NaN
#
#     Programming Assignment #2 (148217)  Programming Assignment #1 (148216)  \
# 1                                  NaN                                 NaN
# 10                                 NaN                                 NaN
# 11                                 NaN                                 NaN
# 12                                 NaN                                 NaN
# 21                                 NaN                                 NaN
#
#     Quiz 4- Requires Respondus LockDown Browser (148207)  \
# 1                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 21                                                NaN
#
#     Quiz 3- Requires Respondus LockDown Browser (148204)  \
# 1                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 21                                                NaN
#
#     Quiz 2- Requires Respondus LockDown Browser (148214)  \
# 1                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 21                                                NaN
#
#     Quiz 1- Requires Respondus LockDown Browser (148211)
# 1                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 21                                                NaN
#
# [5 rows x 100 columns]

# %%
# !pip install --upgrade pandas
import pandas as pd

# Path to the CSV file with many records
# main_csv_file = 'main_file.csv'  # Replace with your file path

# List of CSV file paths to check against
# leactures_CRN = ['file1.csv', 'file2.csv', 'file3.csv']  # Add your CSV file paths here

# Read the main CSV file into a dataframe
# main_df = pd.read_csv(main_csv_file)
missing_students_df
# Create an empty dataframe to store the matching records
matching_records_df = pd.DataFrame(columns=missing_students_df.columns)

# Iterate over each record in the main CSV file
for index, row in missing_students_df.iterrows():
    target_id = row['Student ID']  # Assuming 'id' is the common ID column, replace it with the actual column name

    # Iterate through other CSV files and check for the target ID
    for other_csv_file in leactures_CRN:
        try:
            # Read the other CSV file into a dataframe
            other_df = pd.read_csv(other_csv_file, skiprows=1)

            # Check if the target ID exists in the other dataframe
            if target_id in other_df['Student ID'].values:
                # Append the matching record to the new dataframe
                # pandas verion 2.1.0 use this line
                # matching_records_df = matching_records_df.append(row, ignore_index=True)
                # Append the new row to the DataFrame
                # pandas verion 2.2.0 and newer usethis line
                matching_records_df = pd.concat([matching_records_df, pd.DataFrame([row])], ignore_index=True)
                matching_records_df.loc[matching_records_df["Student ID"]==target_id, "lectures-CRN"]=other_csv_file.replace(".csv","").split('_')[2]
                print(f"Record with ID {target_id} found in {other_csv_file}")
                # Optionally, you can break out of the loop if you only want to find the first occurrence
                break
        except pd.errors.EmptyDataError:
            # Handle empty CSV files if needed
            print(f"Skipping empty file: {other_csv_file}")
        except pd.errors.ParserError:
            # Handle parsing errors if needed
            print(f"Error parsing file: {other_csv_file}")

# Save the matching records to a new CSV file
matching_records_df = matching_records_df.dropna(axis=1, how='all')
matching_records_df.to_csv('ungrouped-Student.csv', index=False)
# Out:
# Record with ID 100918191 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100855555 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100915835 found in lectures-CRNs\roster_CRN_75526.csv
# C:\Users\Abdelrahman Elewah\AppData\Local\Temp\ipykernel_8512\867823977.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '75526' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   matching_records_df.loc[matching_records_df["Student ID"]==target_id, "lectures-CRN"]=other_csv_file.replace(".csv","").split('_')[2]
# Record with ID 100914683 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100905250 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100919355 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100912564 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100924505 found in lectures-CRNs\roster_CRN_75526.csv
# Record with ID 100928091 found in lectures-CRNs\roster_CRN_75526.csv

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.0
